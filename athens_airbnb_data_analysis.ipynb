# %% [markdown]
# # Athens Airbnb Prices Exploratory Data Analysis
#
# This analysis project seeks to explore the pricing trends of Airbnb listings in Athens.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
athens_data = pd.read_csv('listings.csv') 
print(athens_data.shape)
# Out:
# (15584, 79)

# %%
athens_data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy',
#        'number_of_reviews_ly', 'estimated_occupancy_l365d',
#        'estimated_revenue_l365d', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ## Extracting relevant columns that are going to be used in the analysis
# As of this moment we will mainly focus on the Price, Neighbourhood, Number of Bedrooms, Room Type, Yearly Availability and Number of Reviews
# left on the Airbnb listings in the city of Athens, Greece.

# %%
cols = ['id','price', 'neighbourhood_cleansed', 'bedrooms', 'room_type', 'availability_365', 'review_scores_rating']

athens_data = athens_data[cols]
print(athens_data.head())
# Out:
#        id    price  neighbourhood_cleansed  bedrooms        room_type  \
# 0   27262      NaN             ΑΜΠΕΛΟΚΗΠΟΙ       1.0  Entire home/apt
# 1   33945   $45.00          ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       2.0  Entire home/apt
# 2   49489  $160.00  ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ       3.0  Entire home/apt
# 3   60394   $50.00                  ΣΤΑΔΙΟ       1.0  Entire home/apt
# 4  134340      NaN                ΠΑΓΚΡΑΤΙ       1.0  Entire home/apt
#
#    availability_365  review_scores_rating
# 0                 0                  4.86
# 1               269                  4.76
# 2                72                  4.68
# 3                54                  4.97
# 4                 0                  4.68

# %% [markdown]
# ### Data Cleaning

# %%
# Dropping missing values
athens_data = athens_data.dropna()

# Check for duplicate rows
athens_data.duplicated().sum()
# Great no duplicates!
# Out:
# 0

# %%
# Converting $ (which python sees as string data) into float 
athens_data['price'] = athens_data['price'].replace('[$,]', '', regex=True).astype(float)

# %%
print(athens_data.shape)
print(athens_data.head())
# Out:
# (12402, 7)
#        id  price    neighbourhood_cleansed  bedrooms        room_type  \
# 1   33945   45.0            ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       2.0  Entire home/apt
# 2   49489  160.0    ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ       3.0  Entire home/apt
# 3   60394   50.0                    ΣΤΑΔΙΟ       1.0  Entire home/apt
# 5  154243   70.0  ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ       1.0  Entire home/apt
# 6  155654   57.0                  ΑΚΡΟΠΟΛΗ       1.0  Entire home/apt
#
#    availability_365  review_scores_rating
# 1               269                  4.76
# 2                72                  4.68
# 3                54                  4.97
# 5               347                  4.73
# 6                 0                  4.77

# %% [markdown]
# ### Exploring Basic Statistics of the dataset

# %%
print(athens_data.describe())
# Out:
#                  id         price      bedrooms  availability_365  \
# count  1.240200e+04  12402.000000  12402.000000      12402.000000
# mean   7.092409e+17    109.910579      1.413804        258.141509
# std    5.565864e+17    432.627553      0.862274        105.179494
# min    3.394500e+04     10.000000      0.000000          0.000000
# 25%    4.257331e+07     53.000000      1.000000        187.000000
# 50%    8.864636e+17     75.000000      1.000000        306.000000
# 75%    1.196013e+18    111.000000      2.000000        341.000000
# max    1.512450e+18  38000.000000     14.000000        365.000000
#
#        review_scores_rating
# count          12402.000000
# mean               4.772567
# std                0.361351
# min                1.000000
# 25%                4.710000
# 50%                4.870000
# 75%                4.980000
# max                5.000000

# %%
# Boxplot showing the price distribution
plt.figure()
plt.boxplot(athens_data['price'])
plt.title("Price Distribution (Boxplot)")
plt.show()

# %% [markdown]
# ### Outliers
# The descriptive statistics, as well as the boxplot show outlier values, with the most prominent outlier being the $38,000 listing.
# This can be attributed to high-end listings or errors when inputting the data.
#
# For this reason let us explore more on the topic and see the full profile of the top 10 highest outliers.

# %%
# Detecting the major outliers in pricing
athens_data.sort_values("price", ascending=False).head(10)
# Out:
#                         id    price neighbourhood_cleansed  bedrooms  \
# 9466   1111397268060366391  38000.0             ΚΕΡΑΜΕΙΚΟΣ       2.0
# 48                  956538  10000.0             ΚΕΡΑΜΕΙΚΟΣ       2.0
# 11221  1217804556168222792   9429.0            ΕΛΛΗΝΟΡΩΣΩΝ       2.0
# 7310    903465682403602485   9143.0            ΕΛΛΗΝΟΡΩΣΩΝ       1.0
# 8416   1015771770868098586   9000.0         ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       1.0
# 11149  1212731320410286918   9000.0                ΠΑΤΗΣΙΑ       2.0
# 7949    954852605998048706   9000.0         ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       1.0
# 7948    954852591366256728   9000.0         ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       1.0
# 7947    954852385775269403   9000.0         ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       1.0
# 7946    954852338025119049   9000.0         ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ       1.0
#
#              room_type  availability_365  review_scores_rating
# 9466   Entire home/apt                11                  4.81
# 48     Entire home/apt                25                  4.88
# 11221  Entire home/apt               364                  4.33
# 7310   Entire home/apt               365                  5.00
# 8416   Entire home/apt               364                  4.00
# 11149  Entire home/apt               364                  4.50
# 7949   Entire home/apt               364                  4.33
# 7948   Entire home/apt               364                  3.00
# 7947   Entire home/apt               364                  4.40
# 7946   Entire home/apt               364                  4.43

# %% [markdown]
# ## Exploring Average Prices per Neighbourhood and Room Type
# In this segment of the code we will be analysing the Average Price per Athens Neighbourhood, as well as the Average Price per Room Type.
# These findings will also be visualised through the help of barchars for better understanding of the data.

# %%
# Average Price per Neighbourhood
avg_nbhd_price = athens_data.groupby('neighbourhood_cleansed')['price'].mean().sort_values(ascending=False)

print(avg_nbhd_price.sort_values(ascending=False))
# Out:
# neighbourhood_cleansed
# ΑΓΙΟΣ ΝΙΚΟΛΑΟΣ                      709.558824
# ΕΛΛΗΝΟΡΩΣΩΝ                         376.500000
# ΚΕΡΑΜΕΙΚΟΣ                          242.144022
# ΖΑΠΠΕΙΟ                             167.666667
# ΑΚΡΟΠΟΛΗ                            148.973171
# ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ              133.916837
# ΚΟΛΩΝΑΚΙ                            130.618557
# ΒΟΤΑΝΙΚΟΣ                           127.250000
# ΡΗΓΙΛΛΗΣ                            125.400000
# ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ                 121.008203
# ΠΑΤΗΣΙΑ                             115.340741
# ΘΗΣΕΙΟ                              114.629921
# ΓΚΑΖΙ                               112.534653
# ΣΤΑΔΙΟ                              111.455882
# ΛΥΚΑΒΗΤΤΟΣ                           98.646667
# ΙΛΙΣΙΑ                               98.642487
# 1Ο ΝΕΚΡΟΤΑΦΕΙΟ                       89.236842
# ΝΕΟΣ ΚΟΣΜΟΣ                          86.878199
# ΠΕΤΡΑΛΩΝΑ                            86.687500
# ΠΑΓΚΡΑΤΙ                             84.736347
# ΓΟΥΒΑ                                83.821429
# ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ             81.052071
# ΓΟΥΔΙ                                78.615741
# ΠΕΔΙΟ ΑΡΕΩΣ                          78.597561
# ΣΤΑΘΜΟΣ ΛΑΡΙΣΗΣ                      77.764706
# ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ                      71.415948
# ΑΜΠΕΛΟΚΗΠΟΙ                          67.501305
# ΑΚΑΔΗΜΙΑ ΠΛΑΤΩΝΟΣ                    66.552941
# ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ     64.997481
# ΚΟΛΩΝΟΣ                              62.094340
# ΣΕΠΟΛΙΑ                              61.723404
# ΚΥΨΕΛΗ                               61.626050
# ΑΝΩ ΠΑΤΗΣΙΑ                          57.685185
# ΠΛΑΤΕΙΑ ΑΜΕΡΙΚΗΣ                     55.468750
# ΠΟΛΥΓΩΝΟ                             55.307692
# ΝΕΑ ΚΥΨΕΛΗ                           54.695652
# ΝΙΡΒΑΝΑ                              53.568182
# ΓΚΥΖΗ                                52.673684
# ΑΝΩ ΚΥΨΕΛΗ                           50.852174
# ΠΡΟΜΠΟΝΑ                             48.125000
# ΚΟΛΟΚΥΝΘΟΥ                           46.461538
# ΡΙΖΟΥΠΟΛΗ                            46.166667
# ΠΕΝΤΑΓΩΝΟ                            45.000000
# ΑΓΙΟΣ ΕΛΕΥΘΕΡΙΟΣ                     42.333333
# Name: price, dtype: float64

# %%
# Bar-char of the Top 10 most expensive neighbourhoods in Athens
plt.figure()
avg_nbhd_price.head(10).plot(kind='bar')
plt.title("Top 10 Most Expensive Neighbourhoods")
plt.ylabel("Average Price")
plt.show()

# %% [markdown]
# #### On Average "Agios Nikolaos" is the most expensive Athenian Neighbourhood when it comes to Airbnb listings.

# %%
# Average Price per Room Type
avg_room_price = athens_data.groupby('room_type')['price'].mean() 
print(avg_room_price)
# Out:
# room_type
# Entire home/apt    112.007248
# Hotel room         156.230769
# Private room        69.818781
# Shared room         36.321429
# Name: price, dtype: float64

# %%
# Bar-char comparing price by room type
plt.figure()
avg_room_price.plot(kind='bar')
plt.title("Average Price by Room Type")
plt.ylabel("Average Price")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# #### On Average, Hotel Rooms are the most expensive, while Shared Rooms are the cheapest in Athens

# %% [markdown]
# ### Correlation Matrix

# %%
# Correlation between price, number of bedrooms, number of reviews and availability in a year
corr = athens_data[['price', 'bedrooms', 'availability_365', 'review_scores_rating']].corr()
print("\nCorrelation Matrix:")
print(corr)
# Out:
# Correlation Matrix:
#                          price  bedrooms  availability_365  \
# price                 1.000000  0.108801          0.005950
# bedrooms              0.108801  1.000000         -0.013660
# availability_365      0.005950 -0.013660          1.000000
# review_scores_rating  0.004445  0.031514         -0.017524
#
#                       review_scores_rating
# price                             0.004445
# bedrooms                          0.031514
# availability_365                 -0.017524
# review_scores_rating              1.000000

# %% [markdown]
# #### The price is positively correlated to the number of bedrooms in the listings.
